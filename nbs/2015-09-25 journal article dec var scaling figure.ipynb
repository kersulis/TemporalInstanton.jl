# %% [markdown]
# The current paper draft has a figure that plots per-line computation time versus number of decision variables. To pack more information into this figure, Ian suggested I repeat the analysis for one or two more networks and add the results to the plot. He suggested a larger network to compare the RTS-96 against. The issue with using such a network is that wind farms must be carefully placed to secure a numerical solution from the algorithm (rather than `Infinity` or `NaN`).
#
# If the Polish grid has only a few wind farms, we may be able to analyze lines between them, but the vast majority of lines will not return numerical solutions.

# %% [markdown]
# I modified my code to keep track of solution time for each QCQP instance. Testing:

# %%
addprocs(2) # vary number of concurrent processes here
@everywhere include("../src/TemporalInstanton.jl")
@everywhere include("../src/mat2tmpinst.jl")
@everywhere using TemporalInstanton
# Out:
# WARNING: replacing module JLD
# WARNING: replacing module JLD
# WARNING: replacing module MAT_HDF5
# WARNING: replacing module MAT_v5
# WARNING: replacing module MAT
# WARNING: Method definition read(Union{HDF5.HDF5Group, HDF5.HDF5Datatype, HDF5.HDF5Dataset}, Type{Bool}) in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:562 overwritten in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:562.
# WARNING: Method definition read(Union{HDF5.HDF5Group, HDF5.HDF5Datatype, HDF5.HDF5Dataset}, Type{Array{Bool, N<:Any}}) in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:566 overwritten in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:566.
# WARNING: replacing module MAT_HDF5
# WARNING: replacing module MAT_v5
# WARNING: replacing module MAT
# WARNING: Method definition read(Union{HDF5.HDF5Group, HDF5.HDF5Datatype, HDF5.HDF5Dataset}, Type{Bool}) in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:562 overwritten in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:562.
# WARNING: Method definition read(Union{HDF5.HDF5Group, HDF5.HDF5Datatype, HDF5.HDF5Dataset}, Type{Array{Bool, N<:Any}}) in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:566 overwritten in module MAT_HDF5 at /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl:566.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: replacing module MatpowerCases
# WARNING: replacing module MatpowerCases
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
#  in anonymous at multi.jl:892
#  in run_work_thunk at multi.jl:645
#  [inlined code] from multi.jl:892
#  in anonymous at task.jl:63
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 451
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
#  in anonymous at multi.jl:892
#  in run_work_thunk at multi.jl:645
#  [inlined code] from multi.jl:892
#  in anonymous at task.jl:63
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 452
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
#  in anonymous at multi.jl:892
#  in run_work_thunk at multi.jl:645
#  [inlined code] from multi.jl:892
#  in anonymous at task.jl:63
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 451
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in include_string at loading.jl:266
#  in include_from_node1 at ./loading.jl:307
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
#  in anonymous at multi.jl:892
#  in run_work_thunk at multi.jl:645
#  [inlined code] from multi.jl:892
#  in anonymous at task.jl:63
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 452
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 451
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in eval at ./sysimg.jl:14
#  in anonymous at multi.jl:1350
# while loading /home/jkersulis/Documents/Dropbox/InstantonAnew/Jonas Edits/Time-Coupled Instanton/temporal-instanton/src/manipulations.jl, in expression starting on line 452
# WARNING: using TemporalInstanton.mat2tmpinst in module Main conflicts with an existing identifier.
# WARNING: using TemporalInstanton.mat2tmpinst in module Main conflicts with an existing identifier.
# WARNING: using TemporalInstanton.mat2tmpinst in module Main conflicts with an existing identifier.

# %%
include("../src/TemporalInstanton.jl")
using TemporalInstanton
# Out:
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 281
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 295
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 295
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 307
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 307
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 329
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 329
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 329
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 343
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 359
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 396
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 466
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 476
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_HDF5.jl, in expression starting on line 480
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in require at ./loading.jl:243
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include at ./boot.jl:261
#  in include_from_node1 at ./loading.jl:304
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /home/jkersulis/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /home/jkersulis/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /home/jkersulis/.julia/v0.4/MAT/src/MAT_v5.jl, in expression starting on line 78
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.

# %%
# compile everything with this run:
inputData = load_rts96_data(return_as_type=true);
# Thermal model parameters:
inputData.Tamb = 35. # C
inputData.T0 = 60. #46. # initial line steady-state temp

inputData.time_values = 0:30:300 # five minutes in 30-sec steps
inputData.int_length = 300. # seconds = 5 min
Gp,Dp,Rp = inputData.G0,inputData.D0,inputData.R0
inputData.G0 = [0.7*Gp;0.7*Gp;0.7*Gp;0.7*Gp;0.7*Gp;0.7*Gp]
inputData.D0 = [0.9*Dp;0.9*Dp;0.9*Dp;0.9*Dp;0.9*Dp;0.9*Dp]
inputData.R0 = [Rp;1.1*Rp;1.2*Rp;1.3*Rp;1.4*Rp;1.5*Rp]

@time results = solve_temporal_instanton(inputData);

n = length(inputData.k)
nr = length(inputData.Ridx)
T = convert(Int64,length(inputData.G0)/n)
outputData = process_instanton_results(results,n,nr,T,return_as_type=true);

sort(outputData.score)
# Out:
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.Uint is deprecated, use UInt64 instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.None is deprecated, use Union{} instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint16 is deprecated, use UInt16 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# in fillbuf at /home/jkersulis/.julia/v0.4/Zlib/src/Zlib.jl:264
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# in fillbuf at /home/jkersulis/.julia/v0.4/Zlib/src/Zlib.jl:264
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# WARNING: Base.String is deprecated, use AbstractString instead.
# 104-element Array{Float64,1}:
#     0.263788
#     0.327316
#     1.28861
#     2.20415
#     2.32297
#     2.42316
#     4.67876
#     4.86524
#     4.89917
#     5.67827
#     5.93862
#     6.43917
#     6.46089
#     ⋮
#   178.086
#   303.003
#   370.614
#   370.614
#   391.307
#   428.944
#   923.98
#   979.199
#  1319.85
#  1390.03
#  1967.27
#  1967.27
# 9.488825 seconds (2.95 M allocations: 141.821 MB, 0.42% gc time)
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.
# WARNING: Base.Uint8 is deprecated, use UInt8 instead.

# %%
include("../src/mat2tmpinst.jl")
case = "case96"
# maxLines = 10
reps = 50
line_times_96 = Vector{Vector{Float64}}()

for rep in 1:reps
    num_farms_vec = collect(2:2:72)
    gen_count = Vector{Int64}()
    mpc = loadcase(case,describe=false)
    push!(gen_count,length(unique(mpc["gen"][:,1])))

    score_output = Array(Vector{Float64},0)
    sec_elapsed = Vector{Float64}()
    line_times = Vector{Vector{Float64}}()
    bytes_alloc = Vector{Float64}()
    sec_in_gc = Vector{Float64}()
    wind_count = Vector{Int64}()

    for i in 1:length(num_farms_vec)
        num_farms = num_farms_vec[i]
        push!(wind_count,num_farms)
        penetration = 0.7
        d = mat2tmpinst(case,num_farms,penetration)

        # Thermal model parameters:
        d.Tamb = 35. # C
        d.T0 = 60. #46. # initial line steady-state temp

#         d.time_values = 0:600:3600 # one hour in 10-minute steps
#         d.int_length = 3600. # seconds = one hour
        d.time_values = 0:30:300 # five minutes in 30-sec steps
        d.int_length = 300. # seconds = 5 min

        Gp,Dp,Rp = (d.G0, d.D0, d.R0)
        d.G0 = [Gp;Gp;Gp;Gp;Gp;Gp]
        d.D0 = [Dp;Dp;Dp;Dp;Dp;Dp]
        d.R0 = [Rp;Rp;Rp;Rp;Rp;Rp]

        n = length(d.k)
        nr = length(d.Ridx)
        T = convert(Int64,length(d.G0)/n)

        timed_results = @timed solve_temporal_instanton(d);#,maxLines);
        results = timed_results[1]
        o = process_instanton_results(results,n,nr,T,return_as_type=true);
        push!(score_output,o.score)
        push!(sec_elapsed,timed_results[2])
        push!(bytes_alloc,timed_results[3])
        push!(sec_in_gc,timed_results[4])
        push!(line_times,o.linetimes)
    end

    # lines_processed = []
    # for score_vec in score_output
    #     push!(lines_processed, sum(score_vec.!=Inf))
    # end

    push!(line_times_96, [mean(line_times[i]) for i in 1:length(line_times)])
end
# Out:
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: No solution for secular equation; solver returned []
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; num elements too large
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution
# WARNING: c is too small; s(v) = c has no reasonable solution

# %%
line_times_96
# Out:
# 50-element Array{Array{Float64,1},1}:
#  [0.0039068,0.00510604,0.00651918,0.0079063,0.0092515,0.0108353,0.017108,0.0159624,0.018717,0.0220169  …  0.172796,0.16657,0.228121,0.24763,0.228327,0.277969,0.289047,0.392143,0.278394,0.365801]
#  [0.0122951,0.0113803,0.00882993,0.00945509,0.0112724,0.0124714,0.024214,0.0184088,0.0218908,0.0278666  …  0.148818,0.165713,0.200156,0.219863,0.247398,0.235193,0.243539,0.259155,0.274869,0.351996]
#  [0.00501489,0.00641888,0.00971398,0.0129252,0.0154566,0.0146508,0.015866,0.0179876,0.0237229,0.0257819  …  0.148506,0.163688,0.179609,0.191762,0.291267,0.281121,0.269617,0.287454,0.336409,0.344751]
#  [0.00423563,0.00936655,0.00715534,0.00924441,0.010639,0.0140662,0.015609,0.0193623,0.0208399,0.0250016  …  0.186408,0.175149,0.179992,0.191803,0.319161,0.298473,0.267988,0.269164,0.280475,0.311025]
#  [0.00438814,0.00579709,0.00698658,0.00912884,0.0104832,0.0151648,0.0175311,0.0203512,0.0268328,0.0283471  …  0.153227,0.164712,0.183532,0.194372,0.212929,0.248552,0.252095,0.293166,0.390195,0.351074]
#  [0.00436499,0.00614933,0.00770051,0.00906614,0.0104072,0.0145759,0.0149102,0.018926,0.0229739,0.0249341  …  0.17391,0.182369,0.226246,0.189674,0.255483,0.288245,0.255157,0.321081,0.280875,0.304662]
#  [0.0045574,0.0061214,0.00743397,0.00909332,0.0110612,0.0173307,0.0246219,0.0183423,0.0253545,0.025093  …  0.159801,0.168124,0.209139,0.204186,0.24246,0.245394,0.265127,0.306861,0.323387,0.380462]
#  [0.00455438,0.00607451,0.0140364,0.0187301,0.0205767,0.0185367,0.0257014,0.0269543,0.0385183,0.034786  …  0.174156,0.163835,0.222503,0.195205,0.211257,0.233743,0.266969,0.289339,0.352684,0.328136]
#  [0.00496359,0.00713568,0.00793065,0.00972081,0.0116457,0.0132473,0.0176141,0.0195047,0.0243296,0.0252789  …  0.228775,0.185401,0.215405,0.204534,0.232227,0.251708,0.285537,0.277716,0.305431,0.326926]
#  [0.00432778,0.0068587,0.00781381,0.014887,0.0156886,0.0193368,0.0257381,0.0190971,0.0348376,0.0367608  …  0.156073,0.234133,0.214068,0.292351,0.25417,0.270485,0.278607,0.310267,0.283031,0.342738]
#  [0.00464172,0.0061627,0.00719441,0.00978915,0.0115048,0.0150081,0.0223221,0.0230675,0.0254807,0.026021  …  0.173211,0.162849,0.213579,0.21191,0.223597,0.244846,0.268809,0.28325,0.333861,0.318086]
#  [0.00454723,0.00640866,0.00762352,0.00917373,0.0110839,0.0129231,0.0160467,0.0193095,0.023839,0.0246137  …  0.212417,0.204761,0.226394,0.214844,0.239884,0.333471,0.238485,0.251786,0.276641,0.293046]
#  [0.00539615,0.00608547,0.00731795,0.00888137,0.0109555,0.0123785,0.0149024,0.0184726,0.022348,0.0250538  …  0.221593,0.232905,0.21936,0.246701,0.229648,0.320423,0.271242,0.30274,0.380964,0.306822]
#  ⋮
#  [0.0044207,0.00603297,0.00709417,0.00889728,0.0107827,0.0126513,0.0158239,0.0179426,0.0220353,0.0257385  …  0.245125,0.16961,0.210591,0.252531,0.235575,0.247248,0.251494,0.281511,0.305686,0.344772]
#  [0.00476591,0.00651787,0.00794162,0.00890696,0.0106891,0.0129072,0.0202171,0.0194165,0.0228024,0.0275367  …  0.151488,0.160471,0.176641,0.193969,0.262407,0.224405,0.240449,0.256797,0.277886,0.389918]
#  [0.00494257,0.00958151,0.0139264,0.0137121,0.0180574,0.0202769,0.0154022,0.0188574,0.0227863,0.0365828  …  0.166313,0.175021,0.210207,0.233933,0.24867,0.288257,0.283342,0.287734,0.280307,0.298629]
#  [0.00435927,0.00838473,0.0112506,0.0130011,0.0121926,0.0152865,0.0149812,0.0219248,0.0275484,0.026796  …  0.16359,0.172512,0.199677,0.202028,0.257035,0.260059,0.24882,0.332983,0.447767,0.443854]
#  [0.00515966,0.0126238,0.00831754,0.00996823,0.0111927,0.013129,0.0181137,0.0204924,0.0334031,0.0287985  …  0.154086,0.178334,0.186094,0.218035,0.216716,0.242779,0.244742,0.255011,0.284266,0.357601]
#  [0.00689224,0.00793103,0.0103982,0.00964681,0.0104801,0.0207275,0.0261878,0.028653,0.0266694,0.0273733  …  0.196211,0.24576,0.191151,0.202831,0.217583,0.271219,0.234867,0.262544,0.296619,0.320823]
#  [0.00647775,0.00590348,0.00704768,0.0091685,0.0101272,0.0128793,0.0156565,0.0184404,0.0219949,0.0259847  …  0.160761,0.171933,0.222302,0.201116,0.299026,0.263286,0.303925,0.253548,0.282984,0.291719]
#  [0.00436129,0.00593958,0.0073438,0.00883568,0.0108444,0.0127347,0.0161106,0.0172199,0.0214348,0.0240069  …  0.155446,0.159337,0.177054,0.188453,0.239392,0.228842,0.233852,0.248837,0.270672,0.318886]
#  [0.00579473,0.00607943,0.00722016,0.00877663,0.0101406,0.012899,0.0154645,0.0178039,0.0214204,0.0250805  …  0.145011,0.157383,0.176046,0.187999,0.231111,0.44156,0.403652,0.306638,0.328841,0.345682]
#  [0.00484777,0.00626539,0.00879564,0.00884166,0.0104707,0.0133523,0.0217597,0.0295838,0.0406699,0.0324552  …  0.234019,0.20629,0.182742,0.196125,0.262711,0.274282,0.269044,0.265317,0.287692,0.317009]
#  [0.00512251,0.00597607,0.00762263,0.00999318,0.0135178,0.0141603,0.018566,0.0205708,0.0213024,0.0275595  …  0.187731,0.217583,0.296493,0.255269,0.268674,0.292216,0.308934,0.279624,0.272173,0.290099]
#  [0.00453221,0.00587674,0.00741833,0.00903233,0.01107,0.0129811,0.0155356,0.0171052,0.0213242,0.0249314  …  0.153865,0.156599,0.177659,0.192298,0.219545,0.244964,0.254616,0.274801,0.296731,0.366623]

# %%
using JLD
save("../data/line_times_96.jld", "line_times_96", line_times_96)

# %%
include("../src/mat2tmpinst.jl")
case = "case2383wp"
maxLines = 10
reps = 2
line_times_2383 = Vector{Vector{Float64}}()

for rep in 1:reps
    num_farms_vec = collect(200:10:390)
    gen_count = Vector{Int64}()
    mpc = loadcase(case,describe=false)
    push!(gen_count,length(unique(mpc["gen"][:,1])))

    score_output = Array(Vector{Float64},0)
    sec_elapsed = Vector{Float64}()
    line_times = Vector{Vector{Float64}}()
    bytes_alloc = Vector{Float64}()
    sec_in_gc = Vector{Float64}()
    wind_count = Vector{Int64}()

    for i in 1:length(num_farms_vec)
        num_farms = num_farms_vec[i]
        println("wind farms: $num_farms")
        push!(wind_count,num_farms)
        penetration = 0.7
        d = mat2tmpinst(case,num_farms,penetration)

        # Thermal model parameters:
        d.Tamb = 35. # C
        d.T0 = 60. #46. # initial line steady-state temp

#         d.time_values = 0:600:3600 # one hour in 10-minute steps
#         d.int_length = 3600. # seconds = one hour
        
        d.time_values = 0:30:300 # five minutes in 30-sec steps
        d.int_length = 300. # seconds = 5 min
        
        Gp,Dp,Rp = (d.G0, d.D0, d.R0)
        d.G0 = [Gp;Gp;Gp;Gp;Gp;Gp]
        d.D0 = [Dp;Dp;Dp;Dp;Dp;Dp]
        d.R0 = [Rp;Rp;Rp;Rp;Rp;Rp]

        n = length(d.k)
        nr = length(d.Ridx)
        T = convert(Int64,length(d.G0)/n)

        timed_results = @timed solve_temporal_instanton(d,maxLines);
        results = timed_results[1]
        o = process_instanton_results(results,n,nr,T,return_as_type=true);
        push!(score_output,o.score)
        push!(sec_elapsed,timed_results[2])
        push!(bytes_alloc,timed_results[3])
        push!(sec_in_gc,timed_results[4])
        push!(line_times,o.linetimes)
    end

    lines_processed = []
    for score_vec in score_output
        push!(lines_processed, sum(score_vec.!=Inf))
    end

    push!(line_times_2383, [mean(line_times[i]) for i in 1:length(line_times)])
end
# Out:
# wind farms: 200
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 210
# wind farms: 220
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 230
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 240
# WARNING: No solution for secular equation; solver returned []
# wind farms: 250
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 260
# WARNING: No solution for secular equation; solver returned []
# wind farms: 270
# WARNING: No solution for secular equation; solver returned []
# wind farms: 280
# wind farms: 290
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 300
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 310
# WARNING: No solution for secular equation; solver returned []
# wind farms: 320
# wind farms: 330
# wind farms: 340
# WARNING: No solution for secular equation; solver returned []
# wind farms: 350
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; num elements too large
# wind farms: 360
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# wind farms: 370
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 380
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 390
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 200
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 210
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 220
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 230
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# wind farms: 240
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 250
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# wind farms: 260
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 270
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 280
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 290
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 300
# wind farms: 310
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 320
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 330
# wind farms: 340
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 350
# WARNING: No solution for secular equation; num elements too large
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []
# wind farms: 360
# WARNING: No solution for secular equation; solver returned []
# wind farms: 370
# wind farms: 380
# WARNING: No solution for secular equation; solver returned []
# wind farms: 390
# WARNING: No solution for secular equation; solver returned []
# WARNING: No solution for secular equation; solver returned []

# %%
using PyPlot
PyPlot.svg(true)
# Out:
# true

# %%
fig = figure(figsize=(6,5))

x96 = collect(2:2:72)*6
y96 = mean(line_times_96) # s

x2383 = collect(200:10:390)*6
y2383 = mean(line_times_2383) # s

scatter(x96,y96,facecolor="black",alpha=1.,s=20,edgecolor="")
hold(true)
scatter(x2383,y2383,marker="s",facecolor="black",alpha=1.,s=20,edgecolor="")

legend(["case96";"case2383wp"])

# axis([0;450;0;250])
xlabel("Decision variables")
ylabel("Mean QCQP solution time (s)")
# xticks(size=10)
# yticks(size=10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f62fd655d68>)
# PyObject <matplotlib.text.Text object at 0x7f62fd5676a0>

# %%
fig = figure(figsize=(6,5))
hold(true)

x96 = collect(2:2:72)*6

for i in 1:length(line_times_96)
    y96 = line_times_96[i]
    scatter(x96,y96,marker="_",facecolor="black",alpha=0.3)
end

plot(x96,mean(line_times_96))

legend(["Mean";"Individual trials"],loc=4,fontsize=11)

axis([0;450;0;0.6])
xlabel("Decision variables")
ylabel("Mean QCQP solution time (s)")
xticks(size=10)
yticks(size=10)
savefig("../paper2/images/rts-96-scaling-dots.pdf")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f41f2b85390>)

# %%
fig = figure(figsize=(6,5))
hold(true)

x = wind_count*6 # no. of decision vars
y = mean(line_times_agg)*1e3 # ms
yerr_u = [maximum([line_times_agg[i][j] for i in 1:reps]) for j in 1:36]
yerr_l = [minimum([line_times_agg[i][j] for i in 1:reps]) for j in 1:36]

scatter(x,y,facecolor="black",alpha=1.,s=20,edgecolor="")
errorbar(x,y,yerr=yerr_l,fmt="o")

for rep in 1:reps
    scatter(wind_count*6,line_times_agg[rep]*1e3,facecolor="black",alpha=0.6,s=5,edgecolor="")
    # yscale("log")
end


axis([0;450;0;250])
xlabel("Decision variables")
ylabel("Mean QCQP solution time (ms)")
# xticks(size=10)
# yticks(size=10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efbeb77b780>)
# PyObject <matplotlib.text.Text object at 0x7efbeaea8978>
